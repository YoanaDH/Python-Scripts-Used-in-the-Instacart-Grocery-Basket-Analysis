# %% [markdown]
# # Contents
# 1. Importing libraries
# 2. Importing datasets
# 3. Checking the shape of a dataset
# 4. Dropping columns not relevant for the analysis
# 5. Merge
# 6. Download the merged dataset

# %% [markdown]
# # Importing Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing datasets

# %%
# Import the merged pickle dataset
orders_products_combined = pd.read_pickle(r'C:\Users\TemporaryAdmin\Desktop\yoana_learning\Data Analytics\Immension\tasks\my_tasks\part_4\02_data\prepared_data\orders_products_combined.pkl')

# %%
# Import the product dataset
df_products = pd.read_csv(r'C:\Users\TemporaryAdmin\Desktop\yoana_learning\Data Analytics\Immension\tasks\my_tasks\part_4\02_data\prepared_data\products_checked.csv', index_col = False)

# %%
# Check the shape of the dataset
orders_products_combined.shape
# Out:
# (32640698, 14)

# %%
# Check the shape of the dataset
df_products.shape
# Out:
# (49672, 6)

# %%
# Check products dataset upload
df_products.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# Dropping columns not needed in the df_products dataset
df_products.drop(columns = ['Unnamed: 0'])
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49667       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49668       49685                 En Croute Roast Hazelnut Cranberry
# 49669       49686                                   Artisan Baguette
# 49670       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49671       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
# Check products dataset upload
orders_products_combined.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  order_id  user_id eval_set  order_number  \
# 0           0             0   2539329        1    prior             1
# 1           0             0   2539329        1    prior             1
# 2           0             0   2539329        1    prior             1
# 3           0             0   2539329        1    prior             1
# 4           0             0   2539329        1    prior             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  first_order  \
# 0                   2                  8                     NaN         True
# 1                   2                  8                     NaN         True
# 2                   2                  8                     NaN         True
# 3                   2                  8                     NaN         True
# 4                   2                  8                     NaN         True
#
#    product_id  add_to_cart_order  reordered _merge
# ...

# %%
# Dropping columns not needed in the orders_products_combined dataset
orders_products_combined.drop(columns = ['_merge', 'Unnamed: 0','Unnamed: 0.1'])
# Out:
#           order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0          2539329        1    prior             1                   2
# 1          2539329        1    prior             1                   2
# 2          2539329        1    prior             1                   2
# 3          2539329        1    prior             1                   2
# 4          2539329        1    prior             1                   2
# ...            ...      ...      ...           ...                 ...
# 32640693   2977660   206209    prior            13                   1
# 32640694   2977660   206209    prior            13                   1
# 32640695   2977660   206209    prior            13                   1
# 32640696   2977660   206209    prior            13                   1
# 32640697    272231   206209    train            14                   6
#
#           order_hour_of_day  days_since_prior_order  first_order  product_id  \
# ...

# %%
# Merge the two datasets
orders_products_merged = orders_products_combined.merge(df_products, on = ['product_id'], how= 'left', indicator='exists')

# %%
orders_products_merged.head()
# Out:
#    Unnamed: 0_x  Unnamed: 0.1  order_id  user_id eval_set  order_number  \
# 0             0             0   2539329        1    prior             1
# 1             0             0   2539329        1    prior             1
# 2             0             0   2539329        1    prior             1
# 3             0             0   2539329        1    prior             1
# 4             0             0   2539329        1    prior             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  first_order  \
# 0                   2                  8                     NaN         True
# 1                   2                  8                     NaN         True
# 2                   2                  8                     NaN         True
# 3                   2                  8                     NaN         True
# 4                   2                  8                     NaN         True
#
# ...

# %%
orders_products_merged['exists'].value_counts()
# Out:
# both          32404859
# left_only       236409
# right_only           0
# Name: exists, dtype: int64

# %%
# Save the merged file in pkl formalt
path= r'C:\Users\TemporaryAdmin\Desktop\yoana_learning\Data Analytics\Immension\tasks\my_tasks\part_4'
orders_products_merged.to_pickle(os.path.join(path, '02_data','prepared_data','orders_products_merged.pkl'))
